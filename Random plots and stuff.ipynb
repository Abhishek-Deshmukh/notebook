# %%
from numpy import linspace
from IPython.display import display_latex, display

from bokeh import plotting
from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
from numpy import cosh, cos
# linspace
xs = linspace(0, 10, 1000)
# equations
y1s = cosh(2*xs)
# y2s = cos(2*xs)

# the plot
fig = plotting.figure()
fig.line(xs, y1s, color="blue")
# fig.line(xs, y2s, color="red")
show(fig)
# Out:
#   <div class="bk-root" id="70bafe22-ef32-4d5d-b40c-400145a5f6d5" data-root-id="1371"></div>
