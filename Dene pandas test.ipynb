# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv("static/test.csv")

# %%
df.head()
# Out:
#           Data.Matrix  0con_1  0con_2  0con_3  7trt_1  7trt_2  7trt_3  \
# 0  ENSMUSG00000000001    3154    3428    2958    2414    2463    2388
# 1  ENSMUSG00000000003       0       0       0       0       0       0
# 2  ENSMUSG00000000028     439     561     387     189     265     216
# 3  ENSMUSG00000000031      19      19      22       6      28      17
# 4  ENSMUSG00000000037      57      70      66      31      44      27
#
#    15trt_1  15trt_2  15trt_3
# 0     2960     2817     3274
# 1        0        0        0
# 2      243      286      359
# 3       36       28       53
# 4       62       49       60

# %%
df.to_json('make.json',orient="records")

# %%
df2 = pd.read_json('make.json', orient="records")
df2.head()
# Out:
#           Data.Matrix  0con_1  0con_2  0con_3  7trt_1  7trt_2  7trt_3  \
# 0  ENSMUSG00000000001    3154    3428    2958    2414    2463    2388
# 1  ENSMUSG00000000003       0       0       0       0       0       0
# 2  ENSMUSG00000000028     439     561     387     189     265     216
# 3  ENSMUSG00000000031      19      19      22       6      28      17
# 4  ENSMUSG00000000037      57      70      66      31      44      27
#
#    15trt_1  15trt_2  15trt_3
# 0     2960     2817     3274
# 1        0        0        0
# 2      243      286      359
# 3       36       28       53
# 4       62       49       60

# %%
list(df.columns.values)
# Out:
# ['Data.Matrix',
#  '0con_1',
#  '0con_2',
#  '0con_3',
#  '7trt_1',
#  '7trt_2',
#  '7trt_3',
#  '15trt_1',
#  '15trt_2',
#  '15trt_3']
